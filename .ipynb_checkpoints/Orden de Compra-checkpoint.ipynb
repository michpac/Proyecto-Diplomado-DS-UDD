# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %%
oc_detalle = pd.read_excel("InformeMensualOCDetallado200906A.xls")

# %%
oc_detalle.describe()
# Out:
#        region_oc  montosiniva_oc
# count        0.0    3.677700e+04
# mean         NaN    1.382278e+06
# std          NaN    3.724756e+07
# min          NaN    2.800000e-02
# 25%          NaN    5.680000e+04
# 50%          NaN    1.502520e+05
# 75%          NaN    4.636200e+05
# max          NaN    5.404923e+09

# %%
oc_detalle.head()
# Out:
#                                            nombre_oc  \
# 0  compra verduras frescas para Club de Suboficiales
# 1  ADQUISICION PAPEL FOTOCOPIA OFICIO Y CARTA INT...
# 2  ADQUISICION DE PAPEL KRAFF PROGROMA EDUCACION ...
# 3  ADQUISICION DE FRUTAS Y VERDURAS PARA EL JARDI...
# 4                ADQUISICION DE ARTICULOS DE OFICINA
#
#                                       descripcion_oc      codigo_oc  \
# 0  SE REQUIER VERDURAS FRESCAS PARA ESTE CENTRO G...  4750-247-SE09
# 1  ENVIAR A LA SIGUIENTE DIRECCION MELGAREJO  669...   878-311-CM09
# 2  ENVIAR ESTE PEDIDO A LA SIGUIENTE DIRECCION ES...   878-312-CM09
# 3  ADQUISICION DE FRUTAS Y VERDURAS PARA EL JARDI...  5636-144-CM09
# 4  ADQUISICION DE ARTICULOS DE OFICINA. EL DESPAC...  5636-139-CM09
#
#             fechaenvio_oc                    institución_oc  \
# 0 2009-06-01 00:05:20.183              Carabineros de Chile
# 1 2009-06-01 07:27:17.060  Intendencia V Región, Valparaíso
# ...

# %%
oc_detalle.tail()
# Out:
#                                 nombre_oc  \
# 36772  ORDEN DE COMPRA DESDE 3387-30-L109
# 36773  ORDEN DE COMPRA DESDE 3387-30-L109
# 36774  ORDEN DE COMPRA DESDE 3387-30-L109
# 36775   MEMORANDUM Nº73 JEFE LABORATORIO
# 36776   ADQUISICION DE INSUMOS DE CANTINA
#
#                                           descripcion_oc       codigo_oc  \
# 36772  ADQUSICION DE ELEMENTOS PARA REPARACION DE CUA...   3387-171-SE09
# 36773  ADQUSICION DE ELEMENTOS PARA REPARACION DE CUA...   3387-172-SE09
# 36774  ADQUSICION DE ELEMENTOS PARA REPARACION DE CUA...   3387-173-SE09
# 36775  MEMORANDUM Nº73 JEFE LABORATORIO,FLETE INCLUID...  1704-3143-SE09
# 36776  CONTRATO DE SUMINISTROS POR COMPRA DE BEBIDAS ...   3387-167-SE09
#
#                 fechaenvio_oc                   institución_oc  \
# 36772 2009-06-07 23:23:05.530                Ejército de Chile
# 36773 2009-06-07 23:23:20.720                Ejército de Chile
# 36774 2009-06-07 23:23:41.923                Ejército de Chile
# ...
